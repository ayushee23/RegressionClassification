# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import preprocessing
from pandas.tools.plotting import scatter_matrix
from pandas.stats.api import ols
matplotlib.style.use('ggplot')
import statsmodels.formula.api as sm
import statsmodels.stats.api as sms

# %%
kepler_data = pd.read_csv('Ex01_Kepler_Regression.csv')
kepler_data['SemiMajorAxis'] = kepler_data['SemiMajorAxis'].map(lambda x: x**1.5)

# %%
correlations = kepler_data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
names = kepler_data.columns
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(names),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()
correlations
# Out:
#                 SemiMajorAxis    Volume  EscapeVelocity   Density  \
# SemiMajorAxis        1.000000  0.255333        0.243412 -0.618579
# Volume               0.255333  1.000000       -0.015625 -0.153851
# EscapeVelocity       0.243412 -0.015625        1.000000 -0.687354
# Density             -0.618579 -0.153851       -0.687354  1.000000
# OrbitalPeriod        0.934085  0.229391        0.225476 -0.565611
#
#                 OrbitalPeriod
# SemiMajorAxis        0.934085
# Volume               0.229391
# EscapeVelocity       0.225476
# Density             -0.565611
# OrbitalPeriod        1.000000

# %%
scatter_matrix(kepler_data, diagonal='kde', figsize=(10, 8))
plt.show()

# %%
splitend = int(0.8 * len(kepler_data))
kepler_data_shuffled = kepler_data.sample(frac=1)
train, test = kepler_data_shuffled[:splitend], kepler_data_shuffled[splitend:]
x_train = train.ix[:, :-1]
y_train = train.ix[:, -1]
x_test = test.ix[:, :-1]
y_test = test.ix[:, -1]

# %%
model1 = sm.ols(formula='OrbitalPeriod~SemiMajorAxis', data=train).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          OrbitalPeriod   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     456.3
# Date:                Wed, 29 Mar 2017   Prob (F-statistic):           2.49e-34
# Time:                        15:30:10   Log-Likelihood:                -371.76
# No. Observations:                  80   AIC:                             747.5
# Df Residuals:                      78   BIC:                             752.3
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.6966      3.431     -0.203      0.840      -7.527       6.133
# SemiMajorAxis     1.0679      0.050     21.360      0.000       0.968       1.167
# ==============================================================================
# Omnibus:                       25.026   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              273.840
# Skew:                          -0.021   Prob(JB):                     3.44e-60
# Kurtosis:                      12.064   Cond. No.                         82.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
predictions1 = model1.predict(x_test)

# %%
np.mean((y_test - predictions1)**2)**0.5
# Out:
# 21.133294291085267

# %%
plt.scatter(y_test, predictions1)
plt.plot(y_test, predictions1)
plt.show()

# %%
residuals = y_test - predictions1
plt.hist(residuals, bins=5)
plt.show()

# %%
residuals.plot(kind='box')
plt.show()

# %%
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(model1.resid, model1.model.exog)
list(zip(name, test))
# Out:
# [('F statistic', 0.60292781596901401), ('p-value', 0.93835992653216549)]
